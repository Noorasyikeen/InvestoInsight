# %%
import pandas as pd
import numpy as np

# %%
data_df = pd.read_csv(r'/Users/zoeyneo/code/zoeyneo/investoinsight/cleaned_time_series.csv')
data_df.head()
# Out:
#    Unnamed: 0        Date Symbol  Dividend        Volume  fed_funds_rate  \
# 0       29538  2018-07-31    HPQ      0.00  6.845513e+06            1.91
# 1       29037  2018-08-31    CCL      0.50  3.182053e+06            1.91
# 2       29042  2018-08-31    FDS      0.64  2.294333e+05            1.91
# 3       29043  2018-08-31    FDX      0.00  1.211117e+06            1.91
# 4       29045  2018-08-31    HPQ      0.00  6.493083e+06            1.91
#
#            GDP  debt_to_equity       EPS  return_on_equity  quick ratio  \
# 0  4689.905000      -20.385399  0.556258         -0.498019     0.614953
# 1  4717.323667        0.693559  2.417847          0.069238     0.168329
# 2  4717.323667        1.699082  1.801999          0.130867     1.920293
# 3  4717.323667        1.706984  3.150943          0.043551     1.261503
# 4  4717.323667      -25.713635  0.679721         -0.769470     0.613254
#
#    operating_ratio  inventory_turnover  Stock Price
# 0         0.925134            1.953374    19.810163
# 1         0.692598            7.303704    55.871806
# 2         1.234522           27.010998   203.856165
# 3         0.378313            7.585086   224.475233
# 4         0.927927            1.998739    20.428785

# %%
column_names = data_df.columns
print(column_names)
# Out:
# Index(['Unnamed: 0', 'Date', 'Symbol', 'Dividend', 'Volume', 'fed_funds_rate',
#        'GDP', 'debt_to_equity', 'EPS', 'return_on_equity', 'quick ratio',
#        'operating_ratio', 'inventory_turnover', 'Stock Price'],
#       dtype='object')

# %%
data_df = data_df.rename(columns={'Date': 'date',
                                  'Symbol': 'symbol', 
                                  'Dividend': 'dividend',
                                  'Volume': 'volume',
                                  'GDP': 'gdp',
                                  'EPS': 'eps',
                                  'quick ratio': 'quick_ratio',
                                  'Stock Price': 'stock_price'})

# %%
sa18_df = pd.read_csv(r'/Users/zoeyneo/code/zoeyneo/investoinsight/sentiment2018.csv')
sa18_df.head()
# Out:
#    Unnamed: 0                                           Headline        Date  \
# 0           0                   50 biggest movers from yesterday  2018-11-21
# 1           1        36 stocks moving in tuesdays midday session  2018-11-20
# 2           2  shares of agilent technologies are trading up ...  2018-11-20
# 3           3  morgan stanley maintains overweight on agilent...  2018-11-20
# 4           4     26 stocks moving in tuesdays premarket session  2018-11-20
#
#   Stock       Neutral      Positive      Negative
# 0     A  8.389207e-01  3.987503e-02  1.212042e-01
# 1     A  9.999959e-01  1.325494e-07  3.961927e-06
# 2     A  4.851770e-08  1.000000e+00  1.385383e-09
# 3     A  3.539342e-07  9.999996e-01  2.367040e-08
# 4     A  9.999979e-01  1.054393e-07  2.009748e-06

# %%
sa19a_df = pd.read_csv(r'/Users/zoeyneo/code/zoeyneo/investoinsight/sentiment2019p1.csv')
sa19a_df.head()
# Out:
#    Unnamed: 0                                           Headline        Date  \
# 0           0  shares of many healthcare companies are tradin...  2019-05-16
# 1           1                   60 biggest movers from yesterday  2019-05-16
# 2           2      44 stocks moving in wednesdays midday session  2019-05-15
# 3           3  benzinga pros top 10 mostsearched tickers for ...  2019-05-15
# 4           4  bank of america maintains buy on agilent techn...  2019-05-15
#
#   Stock   Neutral      Positive  Negative
# 0     A  0.008474  8.995113e-01  0.092015
# 1     A  0.954836  4.759314e-03  0.040405
# 2     A  0.999997  1.212762e-07  0.000003
# 3     A  0.999995  1.778685e-06  0.000003
# 4     A  0.000008  9.998995e-01  0.000093

# %%
sa19b_df = pd.read_csv(r'/Users/zoeyneo/code/zoeyneo/investoinsight/sentiment2019p1.csv')
sa19b_df.head()
# Out:
#    Unnamed: 0                                           Headline        Date  \
# 0           0  shares of many healthcare companies are tradin...  2019-05-16
# 1           1                   60 biggest movers from yesterday  2019-05-16
# 2           2      44 stocks moving in wednesdays midday session  2019-05-15
# 3           3  benzinga pros top 10 mostsearched tickers for ...  2019-05-15
# 4           4  bank of america maintains buy on agilent techn...  2019-05-15
#
#   Stock   Neutral      Positive  Negative
# 0     A  0.008474  8.995113e-01  0.092015
# 1     A  0.954836  4.759314e-03  0.040405
# 2     A  0.999997  1.212762e-07  0.000003
# 3     A  0.999995  1.778685e-06  0.000003
# 4     A  0.000008  9.998995e-01  0.000093

# %%
sa20_df = pd.read_csv(r'/Users/zoeyneo/code/zoeyneo/investoinsight/sentiment2020.csv')
sa20_df.head()
# Out:
#    Unnamed: 0                                           Headline        Date  \
# 0           0             stocks that hit 52week highs on friday  2020-06-05
# 1           1          stocks that hit 52week highs on wednesday  2020-06-03
# 2           2                      71 biggest movers from friday  2020-05-26
# 3           3         46 stocks moving in fridays midday session  2020-05-22
# 4           4  b of a securities maintains neutral on agilent...  2020-05-22
#
#   Stock   Neutral      Positive  Negative
# 0     A  0.996414  1.911992e-05  0.003567
# 1     A  0.997737  2.388915e-05  0.002239
# 2     A  0.997286  1.869326e-04  0.002527
# 3     A  0.999996  9.135268e-08  0.000004
# 4     A  0.112909  8.801960e-01  0.006895

# %%
sa22_df = pd.read_csv(r'/Users/zoeyneo/code/zoeyneo/investoinsight/sentiment2022.csv')
sa22_df.head()
# Out:
#    Unnamed: 0        Date Stock    pos_ma        neu_ma        neg_ma
# 0           0  2022-09-30     A  1.000000  5.829613e-08  8.049628e-09
# 1           1  2022-10-31     A  1.000000  5.497283e-08  7.521992e-09
# 2           2  2022-11-30     A  0.999996  4.380394e-06  5.380639e-08
# 3           3  2022-12-31     A  0.395974  6.039033e-01  1.226440e-04
# 4           4  2023-01-31     A  0.993029  1.702921e-03  5.268022e-03
